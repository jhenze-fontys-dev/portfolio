# %% [markdown]
# # Testopdracht – NumPy & pandas
#
# Deze notebook test of **NumPy** en **pandas** werken in JupyterLite (Pyodide).

# %%
import numpy as np
import pandas as pd

print("NumPy versie:", np.__version__)
print("pandas versie:", pd.__version__)

# %%
data = np.array([10, 20, 30, 40, 50])
print("Gemiddelde:", data.mean())

# %%
df = pd.DataFrame({
  "product": ["A", "B", "C"],
  "prijs": [12.5, 9.99, 7.45],
  "aantal": [4, 10, 3]
})

df["totaal"] = df["prijs"] * df["aantal"]
df
